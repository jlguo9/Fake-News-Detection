# %%
import pandas as pd

# %%
liar_data = pd.read_csv('liar_data.csv')
pheme_data = pd.read_csv('pheme_data.csv')
buzzfeed_data = pd.read_csv('buzzfeed_data.csv')
kaggle_data_true = pd.read_csv('Kaggle_True.csv')
kaggle_data_fake = pd.read_csv('Kaggle_Fake.csv')

# %%
liar_data.head()
# Out:
#            id        label                                          statement  \
# 0   2635.json        false  Says the Annies List political group supports ...
# 1  10540.json    half-true  When did the decline of coal start? It started...
# 2    324.json  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 3   1123.json        false  Health care reform legislation is likely to ma...
# 4   9028.json    half-true  The economic turnaround started at the end of ...
#
#                               subject         speaker         speaker_title  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
# 2                      foreign-policy    barack-obama             President
# 3                         health-care    blog-posting                   NaN
# 4                        economy,jobs   charlie-crist                   NaN
#
# ...

# %%
pheme_data.head()
# Out:
#                    id  label  \
# 0  580320995266936832      1
# 1  580697361799876608      1
# 2  580320329203093504      1
# 3  581357303405813760      1
# 4  580329886532968448      1
#
#                                                 text  \
# 0  #BREAKING: A Germanwings Airbus A320 has crash...
# 1  BREAKING: Germanwings CEO: Plane victims inclu...
# 2  #A320 @Germanwings flight #4U9525 (registratio...
# 3  #Germanwings co-pilot suffered serious depress...
# 4  Passenger plane carrying 148 people crashes in...
#
#                user_mentions
# 0                 AhronYoung
# 1                        NaN
# 2  germanwings flightradar24
# 3                        NaN
# 4                        NaN

# %%
buzzfeed_data.head()
# Out:
#                 id                                              title  \
# 0   Real_1-Webpage  Another Terrorist Attack in NYC…Why Are we STI...
# 1  Real_10-Webpage  Donald Trump: Drugs a 'Very, Very Big Factor' ...
# 2  Real_11-Webpage  Obama To UN: ‘Giving Up Liberty, Enhances Secu...
# 3  Real_12-Webpage  Trump vs. Clinton: A Fundamental Clash over Ho...
# 4  Real_13-Webpage  President Obama Vetoes 9/11 Victims Bill, Sett...
#
#                                                 text  \
# 0  On Saturday, September 17 at 8:30 pm EST, an e...
# 1  Less than a day after protests over the police...
# 2  Obama To UN: ‘Giving Up Liberty, Enhances Secu...
# 3  Getty Images Wealth Of Nations Trump vs. Clint...
# 4  President Obama today vetoed a bill that would...
#
#                      source  type  images  movies
# 0    http://eaglerising.com  Real       1       0
# 1            http://abcn.ws  Real       1       0
# 2  http://rightwingnews.com  Real       1       1
# ...

# %%
kaggle_data_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
kaggle_data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# ## Extract Text and Label

# %% [markdown]
# ### liar_data

# %%
liar_data = liar_data[['label','statement']]
# transfer "half_true","mostly_true", etc to "true"
liar_data['label'] = liar_data['label'].replace(to_replace='.*true.*', value='true', regex=True)
liar_data['label'] = liar_data['label'].replace(to_replace='.*liar.*', value='false', regex=True)
liar_data['label'] = pd.get_dummies(liar_data['label'])['false']
liar_data = liar_data.rename(columns={'statement': 'text'})

liar_data['label'].value_counts()
# Out:
# 0    10284
# 1     2507
# Name: label, dtype: int64

# %%
# # Solve the dataset imbalance problem
# from imblearn.over_sampling import RandomOverSampler

# liar_y = liar_data['label']
# liar_X = liar_data.drop(columns=['label'])

# oversampler = RandomOverSampler(random_state=42)
# X_resampled, y_resampled = oversampler.fit_resample(liar_X, liar_y)

# liar_data_balanced = pd.concat([X_resampled, y_resampled], axis=1)
# liar_data_balanced
# # liar_0 = liar_data[liar_data['label'] == 0]
# # liar_1 = liar_data[liar_data['label'] == 1]

# # liar_0_sampled = liar_0.sample(n=4000)

# # liar_data_balanced = pd.concat([liar_0_sampled, liar_1])
# # liar_data_balanced

# %% [markdown]
# ### pheme_data

# %%
pheme_data = pheme_data[['label','text']]
pheme_data['label'].value_counts()
# Out:
# 0    4023
# 1    2402
# Name: label, dtype: int64

# %% [markdown]
# ### buzzfeed_data

# %%
# TODO: consider whether merge title into text

buzzfeed_data['label'] = pd.get_dummies(buzzfeed_data['type'])['Fake']
# only use title
buzzfeed_data = buzzfeed_data[['title','label']].rename(columns={'title': 'text'})

buzzfeed_data['label'].value_counts()
# Out:
# 0    91
# 1    91
# Name: label, dtype: int64

# %% [markdown]
# ### kaggle_data

# %%
kaggle_data_true['label'] = ['True']*len(kaggle_data_true)
kaggle_data_fake['label'] = ['Fake']*len(kaggle_data_fake)

kaggle_data = pd.concat([kaggle_data_true, kaggle_data_fake], axis=0).reset_index()[['title','label']]
kaggle_data['label'] = pd.get_dummies(kaggle_data['label'])['Fake']
kaggle_data = kaggle_data.rename(columns={'title': 'text'})

# %%
liar_data.head()
# Out:
#    label                                               text
# 0      1  Says the Annies List political group supports ...
# 1      0  When did the decline of coal start? It started...
# 2      0  Hillary Clinton agrees with John McCain "by vo...
# 3      1  Health care reform legislation is likely to ma...
# 4      0  The economic turnaround started at the end of ...

# %%
pheme_data.head()
# Out:
#    label                                               text
# 0      1  #BREAKING: A Germanwings Airbus A320 has crash...
# 1      1  BREAKING: Germanwings CEO: Plane victims inclu...
# 2      1  #A320 @Germanwings flight #4U9525 (registratio...
# 3      1  #Germanwings co-pilot suffered serious depress...
# 4      1  Passenger plane carrying 148 people crashes in...

# %%
buzzfeed_data.head()
# Out:
#                                                 text  label
# 0  Another Terrorist Attack in NYC…Why Are we STI...      0
# 1  Donald Trump: Drugs a 'Very, Very Big Factor' ...      0
# 2  Obama To UN: ‘Giving Up Liberty, Enhances Secu...      0
# 3  Trump vs. Clinton: A Fundamental Clash over Ho...      0
# 4  President Obama Vetoes 9/11 Victims Bill, Sett...      0

# %%
kaggle_data.head()
# Out:
#                                                 text  label
# 0  As U.S. budget fight looms, Republicans flip t...      0
# 1  U.S. military to accept transgender recruits o...      0
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...      0
# 3  FBI Russia probe helped by Australian diplomat...      0
# 4  Trump wants Postal Service to charge 'much mor...      0

# %% [markdown]
# ## Concat Data

# %%
data = pd.concat([liar_data, pheme_data, buzzfeed_data, kaggle_data], axis=0)
data.head()
# Out:
#    label                                               text
# 0      1  Says the Annies List political group supports ...
# 1      0  When did the decline of coal start? It started...
# 2      0  Hillary Clinton agrees with John McCain "by vo...
# 3      1  Health care reform legislation is likely to ma...
# 4      0  The economic turnaround started at the end of ...

# %%
# save
data.to_csv('data.csv', index=False)
